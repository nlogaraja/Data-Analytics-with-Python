# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading the file/ importing file
data=pd.read_csv("country_profile_variables.csv")

# %% [markdown]
# EDA

# %%
data.head()
# Out:
#           country          Region Surface area (km2)  \
# 0     Afghanistan    SouthernAsia             652864
# 1         Albania  SouthernEurope              28748
# 2         Algeria  NorthernAfrica            2381741
# 3  American Samoa       Polynesia                199
# 4         Andorra  SouthernEurope                468
#
#    Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                           35530                                54.4
# 1                            2930                               106.9
# 2                           41318                                17.3
# 3                              56                               278.2
# 4                              77                               163.8
#
#    Sex ratio (m per 100 f, 2017)  \
# 0                          106.3
# 1                          101.9
# 2                          102.0
# 3                          103.6
# 4                          102.3
#
# ...

# %%
# check column names
data.columns
# Out:
# Index(['country', 'Region', 'Surface area (km2)',
#        'Population in thousands (2017)', 'Population density (per km2, 2017)',
#        'Sex ratio (m per 100 f, 2017)',
#        'GDP: Gross domestic product (million current US$)',
#        'GDP growth rate (annual %, const. 2005 prices)',
#        'GDP per capita (current US$)', 'Economy: Agriculture (% of GVA)',
#        'Economy: Industry (% of GVA)',
#        'Economy: Services and other activity (% of GVA)',
#        'Employment: Agriculture (% of employed)',
#        'Employment: Industry (% of employed)',
#        'Employment: Services (% of employed)',
#        'Unemployment (% of labour force)',
#        'Labour force participation (female/male pop. %)',
#        'Agricultural production index (2004-2006=100)',
#        'Food production index (2004-2006=100)',
#        'International trade: Exports (million US$)',
#        'International trade: Imports (million US$)',
# ...

# %%
# checking how many rows and columns i have
data.shape
# Out:
# (229, 50)

# %%
# checking datatypes of all columns
data.dtypes
# Out:
# country                                                        object
# Region                                                         object
# Surface area (km2)                                             object
# Population in thousands (2017)                                  int64
# Population density (per km2, 2017)                            float64
# Sex ratio (m per 100 f, 2017)                                 float64
# GDP: Gross domestic product (million current US$)               int64
# GDP growth rate (annual %, const. 2005 prices)                 object
# GDP per capita (current US$)                                  float64
# Economy: Agriculture (% of GVA)                                object
# Economy: Industry (% of GVA)                                  float64
# Economy: Services and other activity (% of GVA)               float64
# Employment: Agriculture (% of employed)                        object
# ...

# %%
data.info()
# we have 229 rows
# the index of rows range from 0-228
# we have 50 columns
# all column names
# all datatypes
# if i have any null value or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 50 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   country                                                     229 non-null    object
#  1   Region                                                      229 non-null    object
#  2   Surface area (km2)                                          229 non-null    object
#  3   Population in thousands (2017)                              229 non-null    int64
#  4   Population density (per km2, 2017)                          229 non-null    float64
#  5   Sex ratio (m per 100 f, 2017)                               229 non-null    float64
#  6   GDP: Gross domestic product (million current US$)           229 non-null    int64
# ...

# %%
data.isnull()
# Out:
#      country  Region  Surface area (km2)  Population in thousands (2017)  \
# 0      False   False               False                           False
# 1      False   False               False                           False
# 2      False   False               False                           False
# 3      False   False               False                           False
# 4      False   False               False                           False
# ..       ...     ...                 ...                             ...
# 224    False   False               False                           False
# 225    False   False               False                           False
# 226    False   False               False                           False
# 227    False   False               False                           False
# 228    False   False               False                           False
#
#      Population density (per km2, 2017)  Sex ratio (m per 100 f, 2017)  \
# ...

# %%
data.isnull().sum()
# Out:
# country                                                       0
# Region                                                        0
# Surface area (km2)                                            0
# Population in thousands (2017)                                0
# Population density (per km2, 2017)                            0
# Sex ratio (m per 100 f, 2017)                                 0
# GDP: Gross domestic product (million current US$)             0
# GDP growth rate (annual %, const. 2005 prices)                0
# GDP per capita (current US$)                                  0
# Economy: Agriculture (% of GVA)                               0
# Economy: Industry (% of GVA)                                  0
# Economy: Services and other activity (% of GVA)               0
# Employment: Agriculture (% of employed)                       0
# Employment: Industry (% of employed)                          0
# Employment: Services (% of employed)                          0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - no null values
# - the number of columns is large
# - less number o rows
# - no duplicates
# - many columns are object type

# %% [markdown]
# statistical analysis

# %%
data.head()
# Out:
#           country          Region Surface area (km2)  \
# 0     Afghanistan    SouthernAsia             652864
# 1         Albania  SouthernEurope              28748
# 2         Algeria  NorthernAfrica            2381741
# 3  American Samoa       Polynesia                199
# 4         Andorra  SouthernEurope                468
#
#    Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                           35530                                54.4
# 1                            2930                               106.9
# 2                           41318                                17.3
# 3                              56                               278.2
# 4                              77                               163.8
#
#    Sex ratio (m per 100 f, 2017)  \
# 0                          106.3
# 1                          101.9
# 2                          102.0
# 3                          103.6
# 4                          102.3
#
# ...

# %%
# checking mean of Population in thousands (2017)
data['Population in thousands (2017)'].mean()
# Out:
# 32756.794759825327

# %%
data['Population in thousands (2017)'].median()
# Out:
# 5448.0

# %%
data['Population in thousands (2017)'].mode()
# Out:
# 0        1
# 1       11
# 2       35
# 3       55
# 4       56
# 5      105
# 6      108
# 7      276
# 8      283
# 9     2890
# 10    2930
# Name: Population in thousands (2017), dtype: int64

# %%
data['Population in thousands (2017)'].mode()[9]
# Out:
# 2890

# %%
data['Population in thousands (2017)'].value_counts()
# Out:
# 2890     2
# 55       2
# 11       2
# 56       2
# 276      2
#         ..
# 82114    1
# 28834    1
# 11160    1
# 450      1
# 16530    1
# Name: Population in thousands (2017), Length: 218, dtype: int64

# %%
data['Population in thousands (2017)'].mode()
# Out:
# 0        1
# 1       11
# 2       35
# 3       55
# 4       56
# 5      105
# 6      108
# 7      276
# 8      283
# 9     2890
# 10    2930
# Name: Population in thousands (2017), dtype: int64

# %%
data['Population in thousands (2017)'].min()
# Out:
# 1

# %%
data['Population in thousands (2017)'].max()
# Out:
# 1409517

# %%
#  range
data['Population in thousands (2017)'].max()-data['Population in thousands (2017)'].min()
# Out:
# 1409516

# %%
data['Population in thousands (2017)'].count()
# Out:
# 229

# %%
data['Population in thousands (2017)'].value_counts()
# Out:
# 2890     2
# 55       2
# 11       2
# 56       2
# 276      2
#         ..
# 82114    1
# 28834    1
# 11160    1
# 450      1
# 16530    1
# Name: Population in thousands (2017), Length: 218, dtype: int64

# %%
# how many unique elements we have
data['Population in thousands (2017)'].nunique()
# Out:
# 218

# %%
data['Population in thousands (2017)'].unique()
# Out:
# array([  35530,    2930,   41318,      56,      77,   29784,      15,
#            102,   44271,     105,   24451,    8736,    9828,     395,
#           1493,  164670,     286,    9468,   11429,     375,   11176,
#             61,     808,   11052,      25,    3507,    2292,  209288,
#             31,     429,    7085,   19193,   10864,     546,   16005,
#          24054,   36624,      62,    4659,   14900,     165,   18055,
#           7365,     623, 1409517,   49066,     814,    5261,      17,
#           4906,    4189,   11485,    1180,   10618,   25491,   81340,
#           5734,     957,      74,   10767,   16625,   97553,    6378,
#           1268,    5069,    1310,  104957,       3,      49,     906,
#           5523,   64980,     283,    2025,    2101,    3912,   82114,
#          28834,      35,   11160,     108,     450,     164,   16914,
#           1861,   12717,     778,   10981,       1,    9265,    9722,
# ...

# %%
data['Population in thousands (2017)'].std()
# Out:
# 133275.0799135131

# %%
data['Population in thousands (2017)'].var()
# Out:
# 17762246925.953304

# %%
data.describe()
# Out:
#        Population in thousands (2017)  Population density (per km2, 2017)  \
# count                    2.290000e+02                          229.000000
# mean                     3.275679e+04                          462.824891
# std                      1.332751e+05                         2305.384253
# min                      1.000000e+00                            0.100000
# 25%                      4.310000e+02                           35.900000
# 50%                      5.448000e+03                           88.100000
# 75%                      1.919300e+04                          222.800000
# max                      1.409517e+06                        25969.800000
#
#        Sex ratio (m per 100 f, 2017)  \
# count                     229.000000
# mean                      100.202183
# std                        28.327837
# min                       -99.000000
# 25%                        96.400000
# 50%                        99.000000
# ...

# %%
plt.boxplot(data['Population in thousands (2017)'])
plt.show()

# %%
q1=data['Population in thousands (2017)'].quantile(0.25)
q2=data['Population in thousands (2017)'].quantile(0.50)
q3=data['Population in thousands (2017)'].quantile(0.75)

# %%
q1
# Out:
# 431.0

# %%
q2
# Out:
# 5448.0

# %%
q3
# Out:
# 19193.0

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 18762.0

# %%
ub=q3+1.5*iqr
ub
# Out:
# 47336.0

# %%
lb=q1-1.5*iqr
lb
# Out:
# -27712.0

# %%
data=data[((data['Population in thousands (2017)']<(q1-1.5*iqr))| (data['Population in thousands (2017)']>(q3+1.5*iqr)))]

# %%
data
# Out:
#                               country             Region Surface area (km2)  \
# 16                         Bangladesh       SouthernAsia             147570
# 28                             Brazil       SouthAmerica            8515767
# 45                              China        EasternAsia            9600000
# 46                           Colombia       SouthAmerica            1141748
# 56   Democratic Republic of the Congo       MiddleAfrica            2344858
# 62                              Egypt     NorthernAfrica            1002000
# 67                           Ethiopia      EasternAfrica            1104300
# 72                             France      WesternEurope             551500
# 78                            Germany      WesternEurope             357376
# 95                              India       SouthernAsia            3287263
# 96                          Indonesia  South-easternAsia            1910931
# ...

# %%
plt.boxplot(data['Population in thousands (2017)'])
plt.show()

# %%
df=data[((data['Population in thousands (2017)']>(q1-1.5*iqr)) | (data['Population in thousands (2017)']<(q3+1.5*iqr)))]

# %%
plt.boxplot(df['Population in thousands (2017)'])
plt.show()

# %%
 d=data[((data['Population in thousands (2017)'] < lb) | (data['Population in thousands (2017)'] > ub))]

# %%
e=data[((data['Population in thousands (2017)'] <(q1-1.5*iqr))| (data['Population in thousands (2017)'] > (q3+1.5*iqr)))]

# %%
d
# Out:
#                               country             Region Surface area (km2)  \
# 16                         Bangladesh       SouthernAsia             147570
# 28                             Brazil       SouthAmerica            8515767
# 45                              China        EasternAsia            9600000
# 46                           Colombia       SouthAmerica            1141748
# 56   Democratic Republic of the Congo       MiddleAfrica            2344858
# 62                              Egypt     NorthernAfrica            1002000
# 67                           Ethiopia      EasternAfrica            1104300
# 72                             France      WesternEurope             551500
# 78                            Germany      WesternEurope             357376
# 95                              India       SouthernAsia            3287263
# 96                          Indonesia  South-easternAsia            1910931
# ...

# %%
e
# Out:
#                               country             Region Surface area (km2)  \
# 16                         Bangladesh       SouthernAsia             147570
# 28                             Brazil       SouthAmerica            8515767
# 45                              China        EasternAsia            9600000
# 46                           Colombia       SouthAmerica            1141748
# 56   Democratic Republic of the Congo       MiddleAfrica            2344858
# 62                              Egypt     NorthernAfrica            1002000
# 67                           Ethiopia      EasternAfrica            1104300
# 72                             France      WesternEurope             551500
# 78                            Germany      WesternEurope             357376
# 95                              India       SouthernAsia            3287263
# 96                          Indonesia  South-easternAsia            1910931
# ...

# %%
# distplot
sns.distplot(data['Population in thousands (2017)'],kde=True)
plt.show()
# Out:
# <ipython-input-46-f29b213a3ddc>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Population in thousands (2017)'],kde=True)

# %%
data.head()
# Out:
#                              country        Region Surface area (km2)  \
# 16                        Bangladesh  SouthernAsia             147570
# 28                            Brazil  SouthAmerica            8515767
# 45                             China   EasternAsia            9600000
# 46                          Colombia  SouthAmerica            1141748
# 56  Democratic Republic of the Congo  MiddleAfrica            2344858
#
#     Population in thousands (2017)  Population density (per km2, 2017)  \
# 16                          164670                              1265.0
# 28                          209288                                25.0
# 45                         1409517                               150.1
# 46                           49066                                44.2
# 56                           81340                                35.9
#
#     Sex ratio (m per 100 f, 2017)  \
# 16                          101.7
# 28                           96.6
# ...

# %%
#population in thousands >50,000
#population density >=100

# %%
data['population']=np.where(data['Population in thousands (2017)']>50000,1,0)

# %%
data['density']=np.where(data['Population density (per km2, 2017)']>=100.0,1,0)

# %%
data.head()
# Out:
#                              country        Region Surface area (km2)  \
# 16                        Bangladesh  SouthernAsia             147570
# 28                            Brazil  SouthAmerica            8515767
# 45                             China   EasternAsia            9600000
# 46                          Colombia  SouthAmerica            1141748
# 56  Democratic Republic of the Congo  MiddleAfrica            2344858
#
#     Population in thousands (2017)  Population density (per km2, 2017)  \
# 16                          164670                              1265.0
# 28                          209288                                25.0
# 45                         1409517                               150.1
# 46                           49066                                44.2
# 56                           81340                                35.9
#
#     Sex ratio (m per 100 f, 2017)  \
# 16                          101.7
# 28                           96.6
# ...

# %%
data['count']=1
df1=data[['population','density','count']]
df1.head()
# Out:
#     population  density  count
# 16           1        1      1
# 28           1        0      1
# 45           1        1      1
# 46           0        0      1
# 56           1        0      1

# %%
pd.pivot_table(df1,values='count',index=['population'],
               columns=['density'],
               aggfunc=np.size,
               fill_value=0
            )
# Out:
# density      0   1
# population
# 0            2   0
# 1           10  17

# %%
sns.distplot(data['Population in thousands (2017)'],kde=True)
plt.show()
# Out:
# <ipython-input-54-3305ae5f6840>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Population in thousands (2017)'],kde=True)

# %%
sns.displot(data['Population in thousands (2017)'],kde=True)
plt.show()
