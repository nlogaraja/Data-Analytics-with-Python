# %% [markdown]
# # How to create a Line Plot

# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#defining the dataset
x = np.arange(0,10,0.1)
y = 2*x + 5

#plotting the datapoints
plt.plot(x,y)

# %% [markdown]
# # Cutomizing the Line Plot

# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#defining the dataset
x = np.arange(0,10,1)
y = 2*x + 5
#changing the figure
fig=plt.figure(figsize=(10,5))
#plotting the datapoints
plt.plot(x,y,linewidth = 1.0,linestyle = "--", color = 'b',alpha = 0.5,marker ='*')
plt.title("Line Plot Demo")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend(['My customised line plot'],loc='best')
plt.grid(True)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(0,10,1)
y1 = 2*x+5
y2 = 3*x+10

#Create two or more plots in a fig
plt.subplot(1,2,1)
#PLotting the points
plt.plot(x,y1)
plt.title('Graph1')

plt.subplot(1,2,2)
plt.plot(x,y2)
plt.title('Graph2')
plt.show()

# %% [markdown]
# # How to create a Bar Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#creating the dataset
data = {'apples':20,'Mangoes':15,'Lemon':30,'Oranges':10}
names = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (10,5))
#Creating the bar plot
plt.bar(names,values)
plt.show()

# %% [markdown]
# # Customizing the Bar Chart

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#creating the dataset
data = {'apples':20,'Mangoes':15,'Lemon':30,'Oranges':10}
names = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (10,5))
#Creating the bar plot
plt.barh(names,values,color="yellow")
plt.title("Bar Graph Demo")
plt.xlabel("Fruits")
plt.ylabel("Quantity")
plt.show()

# %% [markdown]
# # How to create a Scatter Plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#Creating the dataset
a =[10,20,30,40,50,60,70,80]
b =[5,3,2,5,6,1,4,2]
x =[1,2,3,4,3,2,1,2]

#Creating the scatter Plot
plt.scatter(a,b)
plt.scatter(a,x)
plt.show()

# %% [markdown]
# # Customizing our Scatter Plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#Creating the dataset
a =[10,20,30,40,50,60,70,80]
b =[5,3,2,5,6,1,4,2]
x =[1,2,3,4,3,2,1,2]

#Creating the scatter Plot
plt.scatter(a,b, c='g', s=200,edgecolors='y',marker='o',alpha =0.5)
plt.scatter(a,x,c='r', s=400,edgecolors='b',marker='4',alpha =1)
plt.legend(['b','x'],loc='best')
plt.title("Scatter Plot Demo")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid(True)
plt.savefig('Scatter Plot.png')
plt.show()
# Out:
# <ipython-input-34-7b2e814371a7>:11: UserWarning: You passed a edgecolor/edgecolors ('b') for an unfilled marker ('4').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(a,x,c='r', s=400,edgecolors='b',marker='4',alpha =1)

# %% [markdown]
# # How to create a Histogram?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#prepraring the dataset

numbers = [10,12,16,19,11,20,26,28,30,38,35,34,45,60,68,64,62,70,78,75,79,85,94,95]
# creating the histogram
plt.hist(numbers, bins = [0,20,40,60,80,100])
plt.show()

# %% [markdown]
# # Customizing the Histogram

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#prepraring the dataset

numbers = [10,12,16,19,11,20,26,28,30,38,35,34,45,60,68,64,62,70,78,75,79,85,94,95]
# creating the histogram
plt.hist(numbers, bins = [0,20,40,60,80,100], edgecolor='yellow', color ='red')
plt.title("Histogram Demo")
plt.xlabel("Range of values")
plt.ylabel("Frequency of values")
plt.grid(True)
plt.savefig("Histogram Plot.png")
plt.show()

# %% [markdown]
# # How to create a Box Plot?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#Data Preparation
total = [20,4,1,30,20,10,20,70,30,10]
order = [10,3,1,15,17,2,30,44,2,1]
discount = [30,10,20,5,10,20,50,60,20,45]
data = list([total, order,discount])
#Plotting the data
plt.boxplot(data)
plt.title("Box Plot Demo")
plt.grid(True)
plt.show()

# %% [markdown]
# # How to create a violin plot?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#Data Preparation
total = [20,4,1,30,20,10,20,70,30,10]
order = [10,3,1,15,17,2,30,44,2,1]
discount = [30,10,20,5,10,20,50,60,20,45]
data = list([total, order,discount])
#Plotting the data
plt.violinplot(data)
plt.title("Violin Plot Demo")
plt.grid(True)
plt.show()

# %% [markdown]
# # How to create a Pie Chart

# %%
#importing the required libraries
import matplotlib.pyplot as plt
# %matplotlib inline

#preparing the dataset
label = ['Dog','Cat','Wolf','Lion']
sizes = [50,45,60,80]

#creating the pie chart
plt.pie(sizes, labels= label,autopct='%0.2f%%',shadow=True, startangle =0,explode = (0.1,0.1,0.1,0.1))
plt.title("Pie Chart Demo")
plt.show()

# %% [markdown]
# # How to create a Doughnut Chart

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#define the dataset
group_names = ["GroupA","GroupB","GroupC"]
group_size = [20,30,50]
size_centre = [1]
a,b,c = [plt.cm.Blues,plt.cm.Reds,plt.cm.Greens]
#Creating the doughnut chart
pie1 = plt.pie(group_size,labels = group_names, radius = 1.2,colors = [a(0.8),b(1.5),c(1.0)])
pie2 = plt.pie(size_centre,radius = 0.8,colors = 'w')
plt.show()

# %% [markdown]
# # How to create a Area Chart?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#define the dataset
x=range(1,15)
y=[1,4,6,8,4,5,3,2,4,1,5,6,8,7]

#creating the area plot
plt.stackplot(x,y,colors = 'b', alpha = 0.5)
#Merge area chart with the line chart
plt.plot(x,y,color = 'g', marker = 'o')
plt.grid(True)
plt.show()

# %%
x=range(1,16)
y=np.arange(0,30,2)
plt.scatter(x,y,c='Cyan',s=100,edgecolor='b',marker='o')
plt.title('Practice Scatter Plot')
plt.legend(['X Value','Y Value'],loc='best')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.grid(True)
